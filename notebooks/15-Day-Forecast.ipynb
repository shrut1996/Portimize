# %%
import numpy as np
import math
import h5py
import matplotlib.pyplot as plt
import pandas as pd
import pandas_datareader.data as web
from datetime import datetime, timedelta
from pandas.tseries.holiday import *
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.models import load_model
# Out:
# Using TensorFlow backend.

# %%
# Importing the training set
stock = 'American Express'
symbol = 'AXP'
forecast = 15
start_date = datetime.today()+timedelta(days=-2000)
end_date = datetime.today()
training_set = web.DataReader(symbol, 'yahoo', start_date, end_date)
print training_set.shape
# Out:
# (1380, 6)

# %%
# Average of the Open, High and Low Prices is the input to our RNN.
# We also convert the Vector form of a single column into a two column matrix-form
training_set = training_set.iloc[:,1:4].values.mean(axis=1)
training_set = np.reshape(training_set, (-1, 1))

# To use Normalisation for the feature Scaling function.
# Default range for MinMaxScaler is 0 to 1, which is what we want. So no arguments in it.
sc = MinMaxScaler()
training_set = sc.fit_transform(training_set)
print training_set

# Getting the inputs and the ouputs
# Restricting the input and output based on how LSTM functions.
X_train = training_set[0:training_set.shape[0]-2*forecast]
y_train = training_set[2*forecast:training_set.shape[0]]

# Reshaping - Adding time interval as a dimension for input.
X_train = np.reshape(X_train, (training_set.shape[0]-2*forecast, 1, 1))
# Out:
# [[ 0.17465334]
#  [ 0.18277976]
#  [ 0.18510159]
#  ...,
#  [ 0.90506292]
#  [ 0.89016447]
#  [ 0.91686558]]

# %%
# Initialising the RNN
model = Sequential()

# Adding the input layer and the LSTM layer
#  memory units, tanh activation function and (None time interval with 1 attribute as input)
model.add(LSTM(units = 5, activation = 'relu', input_shape = (None, 1)))

# Adding the output layer
# 1 nueron in the output layer for 1 dimensional output
model.add(Dense(units = 1))

# Compiling the three layers together.
# Loss helps in manipulation of weights in NN. 
model.compile(optimizer = 'adam', loss = 'mean_squared_error')

# Fitting the RNN to the Training set
model.fit(X_train, y_train, batch_size = 128, epochs = 150)


#model = load_model('15DayModel.h5')
# Out:
# Epoch 1/150
# 1350/1350 [==============================] - 0s 161us/step - loss: 0.3294
# Epoch 2/150
# 1350/1350 [==============================] - 0s 27us/step - loss: 0.3135
# Epoch 3/150
# 1350/1350 [==============================] - 0s 26us/step - loss: 0.2978
# Epoch 4/150
# 1350/1350 [==============================] - 0s 28us/step - loss: 0.2823
# Epoch 5/150
# 1350/1350 [==============================] - 0s 27us/step - loss: 0.2669
# Epoch 6/150
# 1350/1350 [==============================] - 0s 28us/step - loss: 0.2517
# Epoch 7/150
# 1350/1350 [==============================] - 0s 24us/step - loss: 0.2366
# Epoch 8/150
# 1350/1350 [==============================] - 0s 24us/step - loss: 0.2219
# Epoch 9/150
# 1350/1350 [==============================] - 0s 25us/step - loss: 0.2074
# Epoch 10/150
# 1350/1350 [==============================] - 0s 28us/step - loss: 0.1932
# Epoch 11/150
# 1350/1350 [==============================] - 0s 27us/step - loss: 0.1792
# Epoch 12/150
# 1350/1350 [==============================] - 0s 28us/step - loss: 0.1657
# Epoch 13/150
# 1350/1350 [==============================] - 0s 28us/step - loss: 0.1525
# Epoch 14/150
# 1350/1350 [==============================] - 0s 23us/step - loss: 0.1398
# Epoch 15/150
# 1350/1350 [==============================] - 0s 22us/step - loss: 0.1275
# Epoch 16/150
# 1350/1350 [==============================] - 0s 23us/step - loss: 0.1159
# Epoch 17/150
# 1350/1350 [==============================] - 0s 26us/step - loss: 0.1048
# Epoch 18/150
# 1350/1350 [==============================] - 0s 25us/step - loss: 0.0944
# Epoch 19/150
# 1350/1350 [==============================] - 0s 20us/step - loss: 0.0845
# Epoch 20/150
# 1350/1350 [==============================] - 0s 22us/step - loss: 0.0756
# Epoch 21/150
# 1350/1350 [==============================] - 0s 22us/step - loss: 0.0673
# Epoch 22/150
# 1350/1350 [==============================] - 0s 20us/step - loss: 0.0599
# Epoch 23/150
# 1350/1350 [==============================] - 0s 19us/step - loss: 0.0533
# Epoch 24/150
# 1350/1350 [==============================] - 0s 22us/step - loss: 0.0476
# Epoch 25/150
# 1350/1350 [==============================] - 0s 17us/step - loss: 0.0425
# Epoch 26/150
# 1350/1350 [==============================] - 0s 23us/step - loss: 0.0383
# Epoch 27/150
# 1350/1350 [==============================] - 0s 23us/step - loss: 0.0346
# Epoch 28/150
# 1350/1350 [==============================] - 0s 19us/step - loss: 0.0318
# Epoch 29/150
# 1350/1350 [==============================] - 0s 20us/step - loss: 0.0294
# Epoch 30/150
# 1350/1350 [==============================] - 0s 20us/step - loss: 0.0275
# Epoch 31/150
# 1350/1350 [==============================] - 0s 20us/step - loss: 0.0261
# Epoch 32/150
# 1350/1350 [==============================] - 0s 25us/step - loss: 0.0250
# Epoch 33/150
# 1350/1350 [==============================] - 0s 22us/step - loss: 0.0241
# Epoch 34/150
# 1350/1350 [==============================] - 0s 25us/step - loss: 0.0235
# Epoch 35/150
# 1350/1350 [==============================] - 0s 19us/step - loss: 0.0230
# Epoch 36/150
# 1350/1350 [==============================] - 0s 22us/step - loss: 0.0226
# Epoch 37/150
# 1350/1350 [==============================] - 0s 22us/step - loss: 0.0223
# Epoch 38/150
# 1350/1350 [==============================] - 0s 22us/step - loss: 0.0221
# Epoch 39/150
# 1350/1350 [==============================] - 0s 21us/step - loss: 0.0219
# Epoch 40/150
# 1350/1350 [==============================] - 0s 21us/step - loss: 0.0217
# Epoch 41/150
# 1350/1350 [==============================] - 0s 18us/step - loss: 0.0215
# Epoch 42/150
# 1350/1350 [==============================] - 0s 20us/step - loss: 0.0213
# Epoch 43/150
# 1350/1350 [==============================] - 0s 18us/step - loss: 0.0212
# Epoch 44/150
# 1350/1350 [==============================] - 0s 21us/step - loss: 0.0210
# Epoch 45/150
# 1350/1350 [==============================] - 0s 24us/step - loss: 0.0208
# Epoch 46/150
# 1350/1350 [==============================] - 0s 24us/step - loss: 0.0207
# Epoch 47/150
# 1350/1350 [==============================] - 0s 22us/step - loss: 0.0205
# Epoch 48/150
# 1350/1350 [==============================] - 0s 23us/step - loss: 0.0204
# Epoch 49/150
# 1350/1350 [==============================] - 0s 22us/step - loss: 0.0202
# Epoch 50/150
# 1350/1350 [==============================] - 0s 21us/step - loss: 0.0200
# Epoch 51/150
# 1350/1350 [==============================] - 0s 19us/step - loss: 0.0199
# Epoch 52/150
# 1350/1350 [==============================] - 0s 24us/step - loss: 0.0197
# Epoch 53/150
# 1350/1350 [==============================] - 0s 25us/step - loss: 0.0195
# Epoch 54/150
# 1350/1350 [==============================] - 0s 19us/step - loss: 0.0194
# Epoch 55/150
# 1350/1350 [==============================] - 0s 18us/step - loss: 0.0192
# Epoch 56/150
# 1350/1350 [==============================] - 0s 16us/step - loss: 0.0191
# Epoch 57/150
# 1350/1350 [==============================] - 0s 17us/step - loss: 0.0189
# Epoch 58/150
# 1350/1350 [==============================] - 0s 20us/step - loss: 0.0187
# Epoch 59/150
# 1350/1350 [==============================] - 0s 17us/step - loss: 0.0186
# Epoch 60/150
# 1350/1350 [==============================] - 0s 17us/step - loss: 0.0184
# Epoch 61/150
# 1350/1350 [==============================] - 0s 17us/step - loss: 0.0182
# Epoch 62/150
# 1350/1350 [==============================] - 0s 22us/step - loss: 0.0181
# Epoch 63/150
# 1350/1350 [==============================] - 0s 21us/step - loss: 0.0179
# Epoch 64/150
# 1350/1350 [==============================] - 0s 18us/step - loss: 0.0177
# Epoch 65/150
# 1350/1350 [==============================] - 0s 22us/step - loss: 0.0176
# Epoch 66/150
# 1350/1350 [==============================] - 0s 20us/step - loss: 0.0174
# Epoch 67/150
# 1350/1350 [==============================] - 0s 17us/step - loss: 0.0173
# Epoch 68/150
# 1350/1350 [==============================] - 0s 18us/step - loss: 0.0171
# Epoch 69/150
# 1350/1350 [==============================] - 0s 18us/step - loss: 0.0169
# Epoch 70/150
# 1350/1350 [==============================] - 0s 17us/step - loss: 0.0168
# Epoch 71/150
# 1350/1350 [==============================] - 0s 18us/step - loss: 0.0166
# Epoch 72/150
# 1350/1350 [==============================] - 0s 17us/step - loss: 0.0165
# Epoch 73/150
# 1350/1350 [==============================] - 0s 19us/step - loss: 0.0163
# Epoch 74/150
# 1350/1350 [==============================] - 0s 19us/step - loss: 0.0161
# Epoch 75/150
# 1350/1350 [==============================] - 0s 18us/step - loss: 0.0160
# Epoch 76/150
# 1350/1350 [==============================] - 0s 19us/step - loss: 0.0158
# Epoch 77/150
# 1350/1350 [==============================] - 0s 22us/step - loss: 0.0157
# Epoch 78/150
# 1350/1350 [==============================] - 0s 20us/step - loss: 0.0155
# Epoch 79/150
# 1350/1350 [==============================] - 0s 18us/step - loss: 0.0154
# Epoch 80/150
# 1350/1350 [==============================] - 0s 19us/step - loss: 0.0152
# Epoch 81/150
# 1350/1350 [==============================] - 0s 18us/step - loss: 0.0151
# Epoch 82/150
# 1350/1350 [==============================] - 0s 17us/step - loss: 0.0149
# Epoch 83/150
# 1350/1350 [==============================] - 0s 20us/step - loss: 0.0148
# Epoch 84/150
# 1350/1350 [==============================] - 0s 18us/step - loss: 0.0146
# Epoch 85/150
# 1350/1350 [==============================] - 0s 17us/step - loss: 0.0145
# Epoch 86/150
# 1350/1350 [==============================] - 0s 19us/step - loss: 0.0143
# Epoch 87/150
# 1350/1350 [==============================] - 0s 16us/step - loss: 0.0142
# Epoch 88/150
# 1350/1350 [==============================] - 0s 20us/step - loss: 0.0141
# Epoch 89/150
# 1350/1350 [==============================] - 0s 22us/step - loss: 0.0139
# Epoch 90/150
# 1350/1350 [==============================] - 0s 18us/step - loss: 0.0138
# Epoch 91/150
# 1350/1350 [==============================] - 0s 18us/step - loss: 0.0137
# Epoch 92/150
# 1350/1350 [==============================] - 0s 19us/step - loss: 0.0135
# Epoch 93/150
# 1350/1350 [==============================] - 0s 18us/step - loss: 0.0134
# Epoch 94/150
# 1350/1350 [==============================] - 0s 21us/step - loss: 0.0133
# Epoch 95/150
# 1350/1350 [==============================] - 0s 18us/step - loss: 0.0131
# Epoch 96/150
# 1350/1350 [==============================] - 0s 19us/step - loss: 0.0130
# Epoch 97/150
# 1350/1350 [==============================] - 0s 20us/step - loss: 0.0129
# Epoch 98/150
# 1350/1350 [==============================] - 0s 16us/step - loss: 0.0128
# Epoch 99/150
# 1350/1350 [==============================] - 0s 17us/step - loss: 0.0127
# Epoch 100/150
# 1350/1350 [==============================] - 0s 17us/step - loss: 0.0125
# Epoch 101/150
# 1350/1350 [==============================] - 0s 22us/step - loss: 0.0124
# Epoch 102/150
# 1350/1350 [==============================] - 0s 18us/step - loss: 0.0123
# Epoch 103/150
# 1350/1350 [==============================] - 0s 19us/step - loss: 0.0122
# Epoch 104/150
# 1350/1350 [==============================] - 0s 24us/step - loss: 0.0121
# Epoch 105/150
# 1350/1350 [==============================] - 0s 26us/step - loss: 0.0120
# Epoch 106/150
# 1350/1350 [==============================] - 0s 24us/step - loss: 0.0119
# Epoch 107/150
# 1350/1350 [==============================] - 0s 23us/step - loss: 0.0118
# Epoch 108/150
# 1350/1350 [==============================] - 0s 24us/step - loss: 0.0117
# Epoch 109/150
# 1350/1350 [==============================] - 0s 28us/step - loss: 0.0116
# Epoch 110/150
# 1350/1350 [==============================] - 0s 24us/step - loss: 0.0115
# Epoch 111/150
# 1350/1350 [==============================] - 0s 22us/step - loss: 0.0114
# Epoch 112/150
# 1350/1350 [==============================] - 0s 21us/step - loss: 0.0113
# Epoch 113/150
# 1350/1350 [==============================] - 0s 23us/step - loss: 0.0112
# Epoch 114/150
# 1350/1350 [==============================] - 0s 17us/step - loss: 0.0112
# Epoch 115/150
# 1350/1350 [==============================] - 0s 18us/step - loss: 0.0111
# Epoch 116/150
# 1350/1350 [==============================] - 0s 16us/step - loss: 0.0110
# Epoch 117/150
# 1350/1350 [==============================] - 0s 19us/step - loss: 0.0109
# Epoch 118/150
# 1350/1350 [==============================] - 0s 17us/step - loss: 0.0108
# Epoch 119/150
# 1350/1350 [==============================] - 0s 16us/step - loss: 0.0108
# Epoch 120/150
# 1350/1350 [==============================] - 0s 18us/step - loss: 0.0107
# Epoch 121/150
# 1350/1350 [==============================] - 0s 20us/step - loss: 0.0106
# Epoch 122/150
# 1350/1350 [==============================] - 0s 18us/step - loss: 0.0106
# Epoch 123/150
# 1350/1350 [==============================] - 0s 18us/step - loss: 0.0105
# Epoch 124/150
# 1350/1350 [==============================] - 0s 21us/step - loss: 0.0104
# Epoch 125/150
# 1350/1350 [==============================] - 0s 17us/step - loss: 0.0104
# Epoch 126/150
# 1350/1350 [==============================] - 0s 16us/step - loss: 0.0103
# Epoch 127/150
# 1350/1350 [==============================] - 0s 19us/step - loss: 0.0103
# Epoch 128/150
# 1350/1350 [==============================] - 0s 18us/step - loss: 0.0102
# Epoch 129/150
# 1350/1350 [==============================] - 0s 19us/step - loss: 0.0102
# Epoch 130/150
# 1350/1350 [==============================] - 0s 17us/step - loss: 0.0101
# Epoch 131/150
# 1350/1350 [==============================] - 0s 20us/step - loss: 0.0101
# Epoch 132/150
# 1350/1350 [==============================] - 0s 19us/step - loss: 0.0100
# Epoch 133/150
# 1350/1350 [==============================] - 0s 21us/step - loss: 0.0100
# Epoch 134/150
# 1350/1350 [==============================] - 0s 18us/step - loss: 0.0099
# Epoch 135/150
# 1350/1350 [==============================] - 0s 16us/step - loss: 0.0099
# Epoch 136/150
# 1350/1350 [==============================] - 0s 18us/step - loss: 0.0098
# Epoch 137/150
# 1350/1350 [==============================] - 0s 15us/step - loss: 0.0098
# Epoch 138/150
# 1350/1350 [==============================] - 0s 18us/step - loss: 0.0098
# Epoch 139/150
# 1350/1350 [==============================] - 0s 19us/step - loss: 0.0097
# Epoch 140/150
# 1350/1350 [==============================] - 0s 19us/step - loss: 0.0097
# Epoch 141/150
# 1350/1350 [==============================] - 0s 17us/step - loss: 0.0097
# Epoch 142/150
# 1350/1350 [==============================] - 0s 19us/step - loss: 0.0096
# Epoch 143/150
# 1350/1350 [==============================] - 0s 19us/step - loss: 0.0096
# Epoch 144/150
# 1350/1350 [==============================] - 0s 16us/step - loss: 0.0096
# Epoch 145/150
# 1350/1350 [==============================] - 0s 19us/step - loss: 0.0095
# Epoch 146/150
# 1350/1350 [==============================] - 0s 17us/step - loss: 0.0095
# Epoch 147/150
# 1350/1350 [==============================] - 0s 18us/step - loss: 0.0095
# Epoch 148/150
# 1350/1350 [==============================] - ETA: 0s - loss: 0.009 - 0s 17us/step - loss: 0.0095
# Epoch 149/150
# 1350/1350 [==============================] - 0s 21us/step - loss: 0.0094
# Epoch 150/150
# 1350/1350 [==============================] - 0s 23us/step - loss: 0.0094

# %%
#Prediction and visualising results

#Prediction for the training set
real_stock_price_train = sc.inverse_transform(training_set[0:training_set.shape[0]-2*forecast])

predicted_stock_price_train = model.predict(X_train)
predicted_stock_price_train = sc.inverse_transform(predicted_stock_price_train)

plt.plot(real_stock_price_train, color = 'red', label = 'Real ' + stock + 'Stock Price')
plt.plot(predicted_stock_price_train, color = 'blue', label = 'Predicted ' + stock + 'Stock Price')
plt.title(stock +' Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel(stock + 'Stock Price')
plt.legend()
plt.show()

# %%
train_rmse = math.sqrt(mean_squared_error(real_stock_price_train, predicted_stock_price_train))
print 'Training RMSE: ', train_rmse
# Out:
# Training RMSE:  2.46296106616

# %%
# Prediction on test set
test_set = web.DataReader(symbol, 'yahoo', datetime.today()+timedelta(days=-15), datetime.today())
real_stock_price_test = test_set.iloc[:,1:4].values.mean(axis=1)
real_stock_price_test = np.reshape(real_stock_price_test, (-1, 1))
test_set = web.DataReader(symbol, 'yahoo', datetime.today()+timedelta(days=-30), datetime.today()+timedelta(days=-17))
real_stock_price = test_set.iloc[:,1:4].values.mean(axis=1)
real_stock_price = np.reshape(real_stock_price, (-1, 1))
inputs = real_stock_price
inputs = sc.transform(inputs)
inputs = np.reshape(inputs, (real_stock_price.shape[0], 1, 1))
predicted_stock_price_test = model.predict(inputs)
predicted_stock_price_test = sc.inverse_transform(predicted_stock_price_test)

# Visualising the results
plt.plot(real_stock_price_test, color = 'red', label = 'Actual Price')
plt.plot(predicted_stock_price_test, color = 'blue', label = 'Predicted Price')
plt.title(stock +' Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel(stock + ' Stock Price')
plt.legend()
plt.show()

# %%
test_rmse = math.sqrt(mean_squared_error(real_stock_price_test, predicted_stock_price_test))
print 'Test RMSE: ', test_rmse
# Out:
# Test RMSE:  2.31290703405

# %%
model.save('15DayModel.h5')
