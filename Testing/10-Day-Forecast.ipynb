# %%
import numpy as np
import math
import h5py
import matplotlib.pyplot as plt
import pandas as pd
import pandas_datareader.data as web
from datetime import datetime, timedelta
from pandas.tseries.holiday import *
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.models import load_model
# Out:
# Using TensorFlow backend.

# %%
# Importing the training set
stock = 'Facebook'
symbol = 'FB'
forecast = 10
start_date = datetime.today()+timedelta(days=-2000)
end_date = datetime.today()
training_set = web.DataReader(symbol, 'yahoo', start_date, end_date)
print training_set.shape
# Out:
# (1380, 6)

# %%
# Average of the Open, High and Low Prices is the input to our RNN.
# We also convert the Vector form of a single column into a two column matrix-form
training_set = training_set.iloc[:,1:4].values.mean(axis=1)
training_set = np.reshape(training_set, (-1, 1))

# To use Normalisation for the feature Scaling function.
# Default range for MinMaxScaler is 0 to 1, which is what we want. So no arguments in it.
sc = MinMaxScaler()
training_set = sc.fit_transform(training_set)
print training_set

# Getting the inputs and the ouputs
# Restricting the input and output based on how LSTM functions.
X_train = training_set[0:training_set.shape[0]-2*forecast]
y_train = training_set[2*forecast:training_set.shape[0]]

# Reshaping - Adding time interval as a dimension for input.
X_train = np.reshape(X_train, (training_set.shape[0]-2*forecast, 1, 1))
# Out:
# [[ 0.03503963]
#  [ 0.0409324 ]
#  [ 0.04531469]
#  ...,
#  [ 0.97652215]
#  [ 0.96615383]
#  [ 0.96438233]]

# %%
# Initialising the RNN
model = Sequential()

# Adding the input layer and the LSTM layer
# 6 memory units, relu activation function and (None time interval with 1 attribute as input)
model.add(LSTM(units = 6, activation = 'relu', input_shape = (None, 1)))

# Adding the output layer
# 1 nueron in the output layer for 1 dimensional output
model.add(Dense(units = 1))

# Compiling the three layers together.
# Loss helps in manipulation of weights in NN. 
model.compile(optimizer = 'rmsprop', loss = 'mean_squared_error')

# Fitting the RNN to the Training set
model.fit(X_train, y_train, batch_size = 128, epochs = 200)


# model = load_model('10DayModel.h5')
# Out:
# Epoch 1/200
# 1360/1360 [==============================] - 0s 148us/step - loss: 0.2087
# Epoch 2/200
# 1360/1360 [==============================] - 0s 15us/step - loss: 0.1902
# Epoch 3/200
# 1360/1360 [==============================] - 0s 15us/step - loss: 0.1755
# Epoch 4/200
# 1360/1360 [==============================] - 0s 17us/step - loss: 0.1618
# Epoch 5/200
# 1360/1360 [==============================] - 0s 15us/step - loss: 0.1486
# Epoch 6/200
# 1360/1360 [==============================] - 0s 15us/step - loss: 0.1361
# Epoch 7/200
# 1360/1360 [==============================] - 0s 15us/step - loss: 0.1239
# Epoch 8/200
# 1360/1360 [==============================] - 0s 16us/step - loss: 0.1122
# Epoch 9/200
# 1360/1360 [==============================] - 0s 14us/step - loss: 0.1011
# Epoch 10/200
# 1360/1360 [==============================] - 0s 16us/step - loss: 0.0907
# Epoch 11/200
# 1360/1360 [==============================] - 0s 18us/step - loss: 0.0810
# Epoch 12/200
# 1360/1360 [==============================] - 0s 16us/step - loss: 0.0720
# Epoch 13/200
# 1360/1360 [==============================] - 0s 14us/step - loss: 0.0638
# Epoch 14/200
# 1360/1360 [==============================] - 0s 16us/step - loss: 0.0565
# Epoch 15/200
# 1360/1360 [==============================] - 0s 15us/step - loss: 0.0501
# Epoch 16/200
# 1360/1360 [==============================] - 0s 14us/step - loss: 0.0446
# Epoch 17/200
# 1360/1360 [==============================] - 0s 16us/step - loss: 0.0401
# Epoch 18/200
# 1360/1360 [==============================] - 0s 15us/step - loss: 0.0366
# Epoch 19/200
# 1360/1360 [==============================] - 0s 18us/step - loss: 0.0340
# Epoch 20/200
# 1360/1360 [==============================] - 0s 14us/step - loss: 0.0321
# Epoch 21/200
# 1360/1360 [==============================] - 0s 15us/step - loss: 0.0307
# Epoch 22/200
# 1360/1360 [==============================] - 0s 15us/step - loss: 0.0293
# Epoch 23/200
# 1360/1360 [==============================] - 0s 17us/step - loss: 0.0279
# Epoch 24/200
# 1360/1360 [==============================] - 0s 15us/step - loss: 0.0264
# Epoch 25/200
# 1360/1360 [==============================] - 0s 15us/step - loss: 0.0249
# Epoch 26/200
# 1360/1360 [==============================] - 0s 15us/step - loss: 0.0234
# Epoch 27/200
# 1360/1360 [==============================] - 0s 14us/step - loss: 0.0218
# Epoch 28/200
# 1360/1360 [==============================] - 0s 19us/step - loss: 0.0203
# Epoch 29/200
# 1360/1360 [==============================] - 0s 15us/step - loss: 0.0188
# Epoch 30/200
# 1360/1360 [==============================] - 0s 16us/step - loss: 0.0174
# Epoch 31/200
# 1360/1360 [==============================] - 0s 16us/step - loss: 0.0159
# Epoch 32/200
# 1360/1360 [==============================] - 0s 15us/step - loss: 0.0145
# Epoch 33/200
# 1360/1360 [==============================] - 0s 19us/step - loss: 0.0131
# Epoch 34/200
# 1360/1360 [==============================] - 0s 15us/step - loss: 0.0118
# Epoch 35/200
# 1360/1360 [==============================] - 0s 16us/step - loss: 0.0105
# Epoch 36/200
# 1360/1360 [==============================] - 0s 17us/step - loss: 0.0093
# Epoch 37/200
# 1360/1360 [==============================] - 0s 14us/step - loss: 0.0081
# Epoch 38/200
# 1360/1360 [==============================] - 0s 14us/step - loss: 0.0071
# Epoch 39/200
# 1360/1360 [==============================] - 0s 14us/step - loss: 0.0061
# Epoch 40/200
# 1360/1360 [==============================] - 0s 19us/step - loss: 0.0052
# Epoch 41/200
# 1360/1360 [==============================] - 0s 17us/step - loss: 0.0044
# Epoch 42/200
# 1360/1360 [==============================] - 0s 14us/step - loss: 0.0037
# Epoch 43/200
# 1360/1360 [==============================] - 0s 13us/step - loss: 0.0032
# Epoch 44/200
# 1360/1360 [==============================] - 0s 18us/step - loss: 0.0027
# Epoch 45/200
# 1360/1360 [==============================] - 0s 14us/step - loss: 0.0023
# Epoch 46/200
# 1360/1360 [==============================] - 0s 18us/step - loss: 0.0021
# Epoch 47/200
# 1360/1360 [==============================] - 0s 17us/step - loss: 0.0020
# Epoch 48/200
# 1360/1360 [==============================] - 0s 15us/step - loss: 0.0019
# Epoch 49/200
# 1360/1360 [==============================] - 0s 14us/step - loss: 0.0018
# Epoch 50/200
# 1360/1360 [==============================] - 0s 14us/step - loss: 0.0018
# Epoch 51/200
# 1360/1360 [==============================] - 0s 14us/step - loss: 0.0018
# Epoch 52/200
# 1360/1360 [==============================] - 0s 16us/step - loss: 0.0018
# Epoch 53/200
# 1360/1360 [==============================] - 0s 17us/step - loss: 0.0018
# Epoch 54/200
# 1360/1360 [==============================] - 0s 15us/step - loss: 0.0018
# Epoch 55/200
# 1360/1360 [==============================] - 0s 16us/step - loss: 0.0018
# Epoch 56/200
# 1360/1360 [==============================] - 0s 14us/step - loss: 0.0017
# Epoch 57/200
# 1360/1360 [==============================] - 0s 14us/step - loss: 0.0017
# Epoch 58/200
# 1360/1360 [==============================] - 0s 15us/step - loss: 0.0017
# Epoch 59/200
# 1360/1360 [==============================] - 0s 15us/step - loss: 0.0017
# Epoch 60/200
# 1360/1360 [==============================] - 0s 14us/step - loss: 0.0017
# Epoch 61/200
# 1360/1360 [==============================] - 0s 15us/step - loss: 0.0017
# Epoch 62/200
# 1360/1360 [==============================] - 0s 17us/step - loss: 0.0017
# Epoch 63/200
# 1360/1360 [==============================] - 0s 14us/step - loss: 0.0017
# Epoch 64/200
# 1360/1360 [==============================] - 0s 16us/step - loss: 0.0017
# Epoch 65/200
# 1360/1360 [==============================] - 0s 14us/step - loss: 0.0017
# Epoch 66/200
# 1360/1360 [==============================] - 0s 15us/step - loss: 0.0017
# Epoch 67/200
# 1360/1360 [==============================] - 0s 14us/step - loss: 0.0017
# Epoch 68/200
# 1360/1360 [==============================] - 0s 14us/step - loss: 0.0017
# Epoch 69/200
# 1360/1360 [==============================] - 0s 15us/step - loss: 0.0017
# Epoch 70/200
# 1360/1360 [==============================] - 0s 15us/step - loss: 0.0017
# Epoch 71/200
# 1360/1360 [==============================] - 0s 14us/step - loss: 0.0017
# Epoch 72/200
# 1360/1360 [==============================] - 0s 14us/step - loss: 0.0017
# Epoch 73/200
# 1360/1360 [==============================] - 0s 14us/step - loss: 0.0017
# Epoch 74/200
# 1360/1360 [==============================] - 0s 14us/step - loss: 0.0017
# Epoch 75/200
# 1360/1360 [==============================] - 0s 14us/step - loss: 0.0017
# Epoch 76/200
# 1360/1360 [==============================] - 0s 14us/step - loss: 0.0017
# Epoch 77/200
# 1360/1360 [==============================] - 0s 14us/step - loss: 0.0017
# Epoch 78/200
# 1360/1360 [==============================] - 0s 14us/step - loss: 0.0016
# Epoch 79/200
# 1360/1360 [==============================] - 0s 14us/step - loss: 0.0016
# Epoch 80/200
# 1360/1360 [==============================] - 0s 15us/step - loss: 0.0016
# Epoch 81/200
# 1360/1360 [==============================] - 0s 15us/step - loss: 0.0016
# Epoch 82/200
# 1360/1360 [==============================] - 0s 14us/step - loss: 0.0016
# Epoch 83/200
# 1360/1360 [==============================] - 0s 14us/step - loss: 0.0016
# Epoch 84/200
# 1360/1360 [==============================] - 0s 16us/step - loss: 0.0016
# Epoch 85/200
# 1360/1360 [==============================] - 0s 14us/step - loss: 0.0016
# Epoch 86/200
# 1360/1360 [==============================] - 0s 15us/step - loss: 0.0016
# Epoch 87/200
# 1360/1360 [==============================] - 0s 14us/step - loss: 0.0016
# Epoch 88/200
# 1360/1360 [==============================] - 0s 17us/step - loss: 0.0016
# Epoch 89/200
# 1360/1360 [==============================] - 0s 15us/step - loss: 0.0016
# Epoch 90/200
# 1360/1360 [==============================] - 0s 15us/step - loss: 0.0016
# Epoch 91/200
# 1360/1360 [==============================] - 0s 15us/step - loss: 0.0016
# Epoch 92/200
# 1360/1360 [==============================] - 0s 15us/step - loss: 0.0016
# Epoch 93/200
# 1360/1360 [==============================] - 0s 20us/step - loss: 0.0016
# Epoch 94/200
# 1360/1360 [==============================] - 0s 14us/step - loss: 0.0016
# Epoch 95/200
# 1360/1360 [==============================] - 0s 15us/step - loss: 0.0016
# Epoch 96/200
# 1360/1360 [==============================] - 0s 15us/step - loss: 0.0016
# Epoch 97/200
# 1360/1360 [==============================] - 0s 15us/step - loss: 0.0016
# Epoch 98/200
# 1360/1360 [==============================] - 0s 15us/step - loss: 0.0016
# Epoch 99/200
# 1360/1360 [==============================] - 0s 16us/step - loss: 0.0016
# Epoch 100/200
# 1360/1360 [==============================] - 0s 15us/step - loss: 0.0016
# Epoch 101/200
# 1360/1360 [==============================] - 0s 14us/step - loss: 0.0016
# Epoch 102/200
# 1360/1360 [==============================] - 0s 17us/step - loss: 0.0016
# Epoch 103/200
# 1360/1360 [==============================] - 0s 15us/step - loss: 0.0016
# Epoch 104/200
# 1360/1360 [==============================] - 0s 14us/step - loss: 0.0016
# Epoch 105/200
# 1360/1360 [==============================] - 0s 17us/step - loss: 0.0016
# Epoch 106/200
# 1360/1360 [==============================] - 0s 16us/step - loss: 0.0016
# Epoch 107/200
# 1360/1360 [==============================] - 0s 15us/step - loss: 0.0016
# Epoch 108/200
# 1360/1360 [==============================] - 0s 15us/step - loss: 0.0015
# Epoch 109/200
# 1360/1360 [==============================] - 0s 14us/step - loss: 0.0015
# Epoch 110/200
# 1360/1360 [==============================] - 0s 19us/step - loss: 0.0015
# Epoch 111/200
# 1360/1360 [==============================] - 0s 14us/step - loss: 0.0015
# Epoch 112/200
# 1360/1360 [==============================] - 0s 15us/step - loss: 0.0015
# Epoch 113/200
# 1360/1360 [==============================] - 0s 16us/step - loss: 0.0015
# Epoch 114/200
# 1360/1360 [==============================] - 0s 15us/step - loss: 0.0015
# Epoch 115/200
# 1360/1360 [==============================] - 0s 15us/step - loss: 0.0015
# Epoch 116/200
# 1360/1360 [==============================] - 0s 15us/step - loss: 0.0015
# Epoch 117/200
# 1360/1360 [==============================] - 0s 15us/step - loss: 0.0015
# Epoch 118/200
# 1360/1360 [==============================] - 0s 14us/step - loss: 0.0015
# Epoch 119/200
# 1360/1360 [==============================] - 0s 15us/step - loss: 0.0015
# Epoch 120/200
# 1360/1360 [==============================] - 0s 15us/step - loss: 0.0015
# Epoch 121/200
# 1360/1360 [==============================] - 0s 15us/step - loss: 0.0015
# Epoch 122/200
# 1360/1360 [==============================] - 0s 14us/step - loss: 0.0015
# Epoch 123/200
# 1360/1360 [==============================] - 0s 14us/step - loss: 0.0015
# Epoch 124/200
# 1360/1360 [==============================] - 0s 14us/step - loss: 0.0015
# Epoch 125/200
# 1360/1360 [==============================] - 0s 14us/step - loss: 0.0015
# Epoch 126/200
# 1360/1360 [==============================] - 0s 15us/step - loss: 0.0015
# Epoch 127/200
# 1360/1360 [==============================] - 0s 14us/step - loss: 0.0015
# Epoch 128/200
# 1360/1360 [==============================] - 0s 14us/step - loss: 0.0015
# Epoch 129/200
# 1360/1360 [==============================] - 0s 14us/step - loss: 0.0015
# Epoch 130/200
# 1360/1360 [==============================] - 0s 14us/step - loss: 0.0015
# Epoch 131/200
# 1360/1360 [==============================] - 0s 14us/step - loss: 0.0015
# Epoch 132/200
# 1360/1360 [==============================] - 0s 14us/step - loss: 0.0015
# Epoch 133/200
# 1360/1360 [==============================] - 0s 15us/step - loss: 0.0015
# Epoch 134/200
# 1360/1360 [==============================] - 0s 15us/step - loss: 0.0015
# Epoch 135/200
# 1360/1360 [==============================] - 0s 14us/step - loss: 0.0015
# Epoch 136/200
# 1360/1360 [==============================] - 0s 14us/step - loss: 0.0015
# Epoch 137/200
# 1360/1360 [==============================] - 0s 14us/step - loss: 0.0015
# Epoch 138/200
# 1360/1360 [==============================] - 0s 13us/step - loss: 0.0015
# Epoch 139/200
# 1360/1360 [==============================] - 0s 14us/step - loss: 0.0015
# Epoch 140/200
# 1360/1360 [==============================] - 0s 14us/step - loss: 0.0015
# Epoch 141/200
# 1360/1360 [==============================] - 0s 15us/step - loss: 0.0015
# Epoch 142/200
# 1360/1360 [==============================] - 0s 15us/step - loss: 0.0015
# Epoch 143/200
# 1360/1360 [==============================] - 0s 15us/step - loss: 0.0015
# Epoch 144/200
# 1360/1360 [==============================] - 0s 14us/step - loss: 0.0015
# Epoch 145/200
# 1360/1360 [==============================] - 0s 15us/step - loss: 0.0015
# Epoch 146/200
# 1360/1360 [==============================] - 0s 15us/step - loss: 0.0015
# Epoch 147/200
# 1360/1360 [==============================] - 0s 15us/step - loss: 0.0015
# Epoch 148/200
# 1360/1360 [==============================] - 0s 13us/step - loss: 0.0015
# Epoch 149/200
# 1360/1360 [==============================] - 0s 15us/step - loss: 0.0014
# Epoch 150/200
# 1360/1360 [==============================] - 0s 14us/step - loss: 0.0015
# Epoch 151/200
# 1360/1360 [==============================] - 0s 14us/step - loss: 0.0014
# Epoch 152/200
# 1360/1360 [==============================] - 0s 14us/step - loss: 0.0014
# Epoch 153/200
# 1360/1360 [==============================] - 0s 14us/step - loss: 0.0015
# Epoch 154/200
# 1360/1360 [==============================] - 0s 14us/step - loss: 0.0014
# Epoch 155/200
# 1360/1360 [==============================] - 0s 18us/step - loss: 0.0014
# Epoch 156/200
# 1360/1360 [==============================] - 0s 14us/step - loss: 0.0014
# Epoch 157/200
# 1360/1360 [==============================] - 0s 15us/step - loss: 0.0014
# Epoch 158/200
# 1360/1360 [==============================] - 0s 13us/step - loss: 0.0014
# Epoch 159/200
# 1360/1360 [==============================] - 0s 15us/step - loss: 0.0014
# Epoch 160/200
# 1360/1360 [==============================] - 0s 18us/step - loss: 0.0014
# Epoch 161/200
# 1360/1360 [==============================] - 0s 16us/step - loss: 0.0014
# Epoch 162/200
# 1360/1360 [==============================] - 0s 15us/step - loss: 0.0014
# Epoch 163/200
# 1360/1360 [==============================] - 0s 13us/step - loss: 0.0014
# Epoch 164/200
# 1360/1360 [==============================] - 0s 18us/step - loss: 0.0014
# Epoch 165/200
# 1360/1360 [==============================] - 0s 13us/step - loss: 0.0014
# Epoch 166/200
# 1360/1360 [==============================] - 0s 13us/step - loss: 0.0014
# Epoch 167/200
# 1360/1360 [==============================] - 0s 13us/step - loss: 0.0014
# Epoch 168/200
# 1360/1360 [==============================] - 0s 13us/step - loss: 0.0014
# Epoch 169/200
# 1360/1360 [==============================] - 0s 14us/step - loss: 0.0014
# Epoch 170/200
# 1360/1360 [==============================] - 0s 13us/step - loss: 0.0014
# Epoch 171/200
# 1360/1360 [==============================] - 0s 13us/step - loss: 0.0014
# Epoch 172/200
# 1360/1360 [==============================] - 0s 14us/step - loss: 0.0014
# Epoch 173/200
# 1360/1360 [==============================] - 0s 14us/step - loss: 0.0014
# Epoch 174/200
# 1360/1360 [==============================] - 0s 15us/step - loss: 0.0014
# Epoch 175/200
# 1360/1360 [==============================] - 0s 13us/step - loss: 0.0014
# Epoch 176/200
# 1360/1360 [==============================] - 0s 15us/step - loss: 0.0014
# Epoch 177/200
# 1360/1360 [==============================] - 0s 15us/step - loss: 0.0014
# Epoch 178/200
# 1360/1360 [==============================] - 0s 16us/step - loss: 0.0014
# Epoch 179/200
# 1360/1360 [==============================] - 0s 14us/step - loss: 0.0014
# Epoch 180/200
# 1360/1360 [==============================] - 0s 15us/step - loss: 0.0014
# Epoch 181/200
# 1360/1360 [==============================] - 0s 15us/step - loss: 0.0014
# Epoch 182/200
# 1360/1360 [==============================] - 0s 15us/step - loss: 0.0014
# Epoch 183/200
# 1360/1360 [==============================] - 0s 15us/step - loss: 0.0014
# Epoch 184/200
# 1360/1360 [==============================] - 0s 15us/step - loss: 0.0014
# Epoch 185/200
# 1360/1360 [==============================] - 0s 14us/step - loss: 0.0014
# Epoch 186/200
# 1360/1360 [==============================] - 0s 15us/step - loss: 0.0014
# Epoch 187/200
# 1360/1360 [==============================] - 0s 14us/step - loss: 0.0014
# Epoch 188/200
# 1360/1360 [==============================] - 0s 14us/step - loss: 0.0014
# Epoch 189/200
# 1360/1360 [==============================] - 0s 14us/step - loss: 0.0014
# Epoch 190/200
# 1360/1360 [==============================] - 0s 15us/step - loss: 0.0014
# Epoch 191/200
# 1360/1360 [==============================] - 0s 16us/step - loss: 0.0014
# Epoch 192/200
# 1360/1360 [==============================] - 0s 16us/step - loss: 0.0014
# Epoch 193/200
# 1360/1360 [==============================] - 0s 14us/step - loss: 0.0014
# Epoch 194/200
# 1360/1360 [==============================] - 0s 15us/step - loss: 0.0014
# Epoch 195/200
# 1360/1360 [==============================] - 0s 14us/step - loss: 0.0014
# Epoch 196/200
# 1360/1360 [==============================] - 0s 14us/step - loss: 0.0014
# Epoch 197/200
# 1360/1360 [==============================] - 0s 14us/step - loss: 0.0014
# Epoch 198/200
# 1360/1360 [==============================] - 0s 15us/step - loss: 0.0014
# Epoch 199/200
# 1360/1360 [==============================] - 0s 14us/step - loss: 0.0014
# Epoch 200/200
# 1360/1360 [==============================] - 0s 13us/step - loss: 0.0014

# %%
#Prediction and visualising results

#Prediction for the training set
real_stock_price_train = sc.inverse_transform(training_set[0:training_set.shape[0]-2*forecast])

predicted_stock_price_train = model.predict(X_train)
predicted_stock_price_train = sc.inverse_transform(predicted_stock_price_train)

plt.plot(real_stock_price_train, color = 'red', label = 'Real ' + stock + 'Stock Price')
plt.plot(predicted_stock_price_train, color = 'blue', label = 'Predicted ' + stock + 'Stock Price')
plt.title(stock +' Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel(stock + 'Stock Price')
plt.legend()
plt.show()

# %%
train_rmse = math.sqrt(mean_squared_error(real_stock_price_train, predicted_stock_price_train))
print 'Training RMSE: ', train_rmse
# Out:
# Training RMSE:  3.35045270256

# %%
# Prediction on test set
test_set = web.DataReader(symbol, 'yahoo', datetime.today()+timedelta(days=-15), datetime.today())
real_stock_price_test = test_set.iloc[:,1:4].values.mean(axis=1)
real_stock_price_test = np.reshape(real_stock_price_test, (-1, 1))
test_set = web.DataReader(symbol, 'yahoo', datetime.today()+timedelta(days=-30), datetime.today()+timedelta(days=-17))
real_stock_price = test_set.iloc[:,1:4].values.mean(axis=1)
real_stock_price = np.reshape(real_stock_price, (-1, 1))
inputs = real_stock_price
inputs = sc.transform(inputs)
inputs = np.reshape(inputs, (real_stock_price.shape[0], 1, 1))
predicted_stock_price_test = model.predict(inputs)
predicted_stock_price_test = sc.inverse_transform(predicted_stock_price_test)

# Visualising the results
plt.plot(real_stock_price_test, color = 'red', label = 'Actual Price')
plt.plot(predicted_stock_price_test, color = 'blue', label = 'Predicted Price')
plt.title(stock +' Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel(stock + ' Stock Price')
plt.legend()
plt.show()

# %%
test_rmse = math.sqrt(mean_squared_error(real_stock_price_test, predicted_stock_price_test))
print 'Test RMSE: ', test_rmse
# Out:
# Test RMSE:  3.88662459428

# %%
model.save('10DayModel.h5')
